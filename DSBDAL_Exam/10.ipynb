# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("iris")

# %%
print("Features:")
for feature in df.columns:
    if df[feature].dtype == 'int64' or df[feature].dtype == 'float64':
        print(f"Type of {feature}: Numeric")
    else:
        print(f"Type of {feature}: Nominal")
    if df[feature].dtype == 'object':
        print(f"  Unique values: {df[feature].unique()}")
# Out:
# Features:
# Type of sepal_length: Numeric
# Type of sepal_width: Numeric
# Type of petal_length: Numeric
# Type of petal_width: Numeric
# Type of species: Nominal
#   Unique values: ['setosa' 'versicolor' 'virginica']

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
plt.hist(df.sepal_length)
plt.grid(True)

# %%
plt.hist(df.sepal_width)
plt.grid(True)

# %%
plt.hist(df.petal_length)
plt.grid(True)

# %%
plt.hist(df.petal_width,color= 'green')
plt.grid(True)

# %%
plt.boxplot(df['petal_width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1efb3eb5100>,
#   <matplotlib.lines.Line2D at 0x1efb3eb53d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1efb3eb5c70>,
#   <matplotlib.lines.Line2D at 0x1efb3ed6700>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1efb3eb54c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1efb3ed6d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1efb3ed6910>],
#  'means': []}

# %%
plt.boxplot(df.petal_length)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1efb3d26370>,
#   <matplotlib.lines.Line2D at 0x1efb3d26f40>],
#  'caps': [<matplotlib.lines.Line2D at 0x1efb3d26520>,
#   <matplotlib.lines.Line2D at 0x1efb3d260d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1efb3d48ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1efb3d26ca0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1efb3d405e0>],
#  'means': []}

# %%
plt.boxplot(df.sepal_width)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1efb3a68f10>,
#   <matplotlib.lines.Line2D at 0x1efb3a68850>],
#  'caps': [<matplotlib.lines.Line2D at 0x1efb3a68b20>,
#   <matplotlib.lines.Line2D at 0x1efb3a74640>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1efb3a68280>],
#  'medians': [<matplotlib.lines.Line2D at 0x1efb3a74a00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1efb3a74ac0>],
#  'means': []}

# %%
plt.boxplot(df.sepal_length)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1efb3ec8d90>,
#   <matplotlib.lines.Line2D at 0x1efb3de92b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1efb3de9580>,
#   <matplotlib.lines.Line2D at 0x1efb3de9c70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1efb3ec8a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1efb3de9e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1efb3de9760>],
#  'means': []}

# %%
sns.pairplot(df)

# %%
sns.scatterplot(y = df['petal_width'], x = df['sepal_width'])
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>
